# %%
import os

# %%
dict= {
    "key1": "value1",
    "key2": "value2"
}

# %%
dict['key1']
# Out:
# 'value1'

# %%
from box import ConfigBox 
dict2=ConfigBox(dict)
dict2.key1
# Out:
# 'value1'

# %%
def product(a: int, b: int) -> int:
    return a * b

# %%
prod = product('2', 3)
print(f"The product is: {type(prod)}")
# Out:
# The product is: <class 'str'>
